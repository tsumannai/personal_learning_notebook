# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import HTML
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Polynomial Curve Fitting

# %% [markdown]
# Polynomial curve fitting is used to demonstrate regression problems. Particularly to make preditions where of value $\hat{t}$ for some new value $\hat{x}$.
#
# $$y(x,w) = w_0 + w_1 x + w_2x^2 + ... + w_Mx^M = \sum_{j=0}^Mw_jx^j$$
#
# Where $M$ is the order of the polynomial, and $x^j$ denotes $x$ raised to the power of $j$. The polynomial coefficients are denoted by vecotr $w$.

# %% [markdown]
# From training data, coefficients are determined by minimizing and error function. An example would be:
#
# $$E(w) = \frac{1}{2}\sum_{n=1}^N\{y(x_n,w)-t_n\}^2$$

# %% [markdown]
# For example, we will use the function $sin(2{\pi}x)$ with 50 overvations in the range[0,1].

# %%
# Random Seed
np.random.seed(42)
# Observations
n = 100
# Evenly spaced array
x = np.linspace(0,1,n)
# Mock data
y = np.sin(2*np.pi*x)
# Noise with gaussian distribution
noise = np.random.normal(0,0.3,n)
x_random = np.random.choice(x,n)
y_new = np.sin(2*np.pi*x_random)+noise

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(x,y)
ax[0].title.set_text('Synthetic Data')
ax[1].scatter(x_random,y_new)
ax[1].title.set_text('Synthetic Data with Gaussian Noise')

# %% [markdown]
# ## Predictons of Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
# Train test split
X_train, X_test, y_train, y_test = train_test_split(x_random, y_new, test_size=0.20,random_state=42)
degrees = [0,1,3,6,9,16]
fig, ax = plt.subplots(6,2)
fig.suptitle('Training and Test Data with Preditions n = 100', fontsize=10)

error = np.zeros(shape=(len(degrees), 3))
for n in range(0, len(degrees)):
    # for n in degrees:
    poly = PolynomialFeatures(degree=degrees[n])
    
    # Transform X_train using polynomial features
    X_train_poly = poly.fit_transform(X_train.reshape(-1, 1))
    
    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    
    # Make predictions on the transformed training data
    y_train_pred = model.predict(X_train_poly)
    
    # Sort train data
    sorted_indices = X_train.argsort()
    X_train_sorted = X_train[sorted_indices]
    y_train_sorted = y_train[sorted_indices]
    y_train_pred_sorted = y_train_pred[sorted_indices]
    
    
    # Perform transform on test data
    X_test_poly = poly.fit_transform(X_test.reshape(-1, 1))
    y_test_pred = model.predict(X_test_poly)
    # Sort test data
    sorted_indices = X_test.argsort()
    X_test_sorted = X_test[sorted_indices]
    y_test_sorted = y_test[sorted_indices]
    y_test_pred_sorted = y_test_pred[sorted_indices]
    
    # Plot the original training data
    ax[n,0].scatter(X_train_sorted, y_train_sorted, color='blue', label='Actual')
    ax[n,0].plot(X_train_sorted, y_train_pred_sorted, color='red', label='Predicted')
    ax[n,0].set_title('Training Data Actuals and Predictions, M = {}'.format(degrees[n]))
    ax[n,0].legend(loc="upper right")
    ax[n,1].scatter(X_test_sorted, y_test_sorted, color='blue', label='Actual')
    ax[n,1].plot(X_train_sorted, y_train_pred_sorted, color='red', label='Predicted')
    ax[n,1].set_title('Test Data Actuals and Predictions')
    ax[n,1].legend(loc="upper right")

    train_rms = mean_squared_error(y_train_sorted, y_train_pred_sorted, squared=False)
    test_rms = mean_squared_error(y_test_sorted, y_test_pred_sorted, squared=False)

    
    error[n][0] = degrees[n]
    error[n][1] = train_rms
    error[n][2] = test_rms
fig.set_size_inches(8, 16)
fig.tight_layout()
fig.subplots_adjust(top=0.95)

# %% [markdown]
# Plots of predicted polynomials with different orders are shown. When $M = 0$, we only have $y(x,w) = w_0$ resulting in a horizontal line, for $M = 1$ we have $y(x,w) = w_0 +w_1x$ similar to a straight line graph formula.
#
# A lower polynomial order like $M = 3$ does a reasonably good job at generalising the function. Higher orders lead to over fitting and may not be representative of test data and only the training data.

# %% [markdown]
# ## Error Function RMSE

# %% [markdown]
# $$E_{RMS} = \sqrt{\frac{2E(w*)}{N}}$$
#
# A higher polynomial may result in lower errors for training data but generlization performance may be worse. Generalization performance can be seen by calculating errors in the predicted test set.

# %% [markdown]
# For further values of $M$ will increase the number of features dramatically (dimensions).
#
# *The common theme of these problems is that when the dimensionality increases, the volume of the space increases so fast that the available data become sparse. In order to obtain a reliable result, the amount of data needed often grows exponentially with the dimensionality. Also, organizing and searching data often relies on detecting areas where objects form groups with similar properties; in high dimensional data, however, all objects appear to be sparse and dissimilar in many ways, which prevents common data organization strategies from being efficient.*

# %% [markdown]
# For higher order polynomials, we should expect error to tend towards zero for training data as M gets closer the number of points the training has. As explained, with a higher volume of data we can push the dimensionality of the model higher while retaining a lower error on our test data. However, for smaller dataset sizes, we can see that the model overfits the training data much more easier causing higher errors after a certain point for test data when dataset size is smaller.

# %%
df_error = pd.DataFrame(error).rename({0:'M',1:'Training',2:'Test'}, axis = 1)

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(5,5)
ax.plot(df_error['M'], df_error['Training'], color='green', marker='o', linestyle='dashed',
     linewidth=2, markersize=8, label = 'Training Error')

ax.plot(df_error['M'], df_error['Test'], color='red', marker='o', linestyle='dashed',
     linewidth=2, markersize=8, label = 'Test Error')
ax.legend()
ax.set_xlabel('M')
ax.set_ylabel('RMSE')
ax.set_title('Training and Test Error, n = 100')
# Out:
# Text(0.5, 1.0, 'Training and Test Error, n = 100')

# %%
fig, ax = plt.subplots(1,1)
fig.set_size_inches(5,5)
ax.plot(df_error['M'], df_error['Training'], color='green', marker='o', linestyle='dashed',
     linewidth=2, markersize=8, label = 'Training Error')

ax.plot(df_error['M'], df_error['Test'], color='red', marker='o', linestyle='dashed',
     linewidth=2, markersize=8, label = 'Test Error')
ax.legend()
ax.set_xlabel('M')
ax.set_ylabel('RMSE')
ax.set_title('Training and Test Error, n = 20')  
# fig.tight_layout()
# Out:
# Text(0.5, 1.0, 'Training and Test Error, n = 20')

# %% [markdown]
# ## Regularization

# %% [markdown]
# It would seem more reasonable to choose the complexity of the model (orders of M in this example) with the complexity of the problem, and not limit ourselves with how much data we have. By adopting a bayesian approach, over-fitting can be avoided. Using a bayesian approach, there is less difficulty from employing models with more paramters than datapoints.
#
# We can also employ regularisation to penalize using more parameters and reduce overfitting. As a modification of the error function, where $\lambda$ governs the importance of adding more paramters. These techniques are known as *shrinkage* methods because they reduce the value of coefficients.
#
# $$E(w) = \frac{1}{2}\sum_{n=1}^N\{y(x_n,w)-t_n\}^2 + \frac{\lambda}{2}||w||^2$$
