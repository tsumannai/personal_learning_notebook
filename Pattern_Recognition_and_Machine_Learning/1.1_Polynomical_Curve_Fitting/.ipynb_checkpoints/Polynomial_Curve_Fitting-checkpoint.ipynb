# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import HTML
# %matplotlib inline

# %% [markdown]
# # Polynomial Curve Fitting

# %% [markdown]
# Polynomial curve fitting is used to demonstrate regression problems. Particularly to make preditions where of value $\hat{t}$ for some new value $\hat{x}$.
#
# $$y(x,w) = w_0 + w_1 x + w_2x^2 + ... + w_Mx^M = \sum_{j=0}^Mw_jx^j$$
#
# Where $M$ is the order of the polynomial, and $x^j$ denotes $x$ raised to the power of $j$. The polynomial coefficients are denoted by vecotr $w$.

# %% [markdown]
# From training data, coefficients are determined by minimizing and error function. An example would be:
#
# $$E(w) = \frac{1}{2}\sum_{n=1}^N\{y(x_n,w)-t_n\}^2$$

# %% [markdown]
# For example, we will use the function $sin(2{\pi}x)$ with 100 overvations in the range[0,1].

# %%
# Random Seed
np.random.seed(42)
# Evenly spaced array
x = np.linspace(0,1,100)
# Mock data
y = np.sin(2*np.pi*x)
# Noise with gaussian distribution
noise = np.random.normal(0,0.3,100)
x_random = np.random.choice(x,100)
y_new = np.sin(2*np.pi*x_random)+noise

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(x,y)
ax[0].title.set_text('Synthetic Data')
ax[1].scatter(x_random,y_new)
ax[1].title.set_text('Synthetic Data with Gaussian Noise')

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
train_test_split(x_random, y_new, test_size=0.20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 train_test_split(x_random, y_new, test_size=0.20)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bishop/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bishop/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:75, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      72 constraints = [make_constraint(constraint) for constraint in constraints]
#      74 for constraint in constraints:
# ---> 75     if constraint.is_satisfied_by(param_val):
#      76         # this constraint is satisfied, no need to check further.
#      77         break
#      78 else:
#      79     # No constraint is satisfied, raise with an informative message.
#      80
#      81     # Ignore constraints that we don't want to expose in the error message,
#      82     # i.e. options that are for internal purpose or not officially supported.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bishop/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:564, in _RandomStates.is_satisfied_by(self, val)
#     563 def is_satisfied_by(self, val):
# --> 564     return any(c.is_satisfied_by(val) for c in self._constraints)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bishop/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:564, in <genexpr>(.0)
#     563 def is_satisfied_by(self, val):
# --> 564     return any(c.is_satisfied_by(val) for c in self._constraints)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/bishop/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:294, in _InstancesOf.is_satisfied_by(self, val)
#     293 def is_satisfied_by(self, val):
# --> 294     return isinstance(val, self.type)
#
# TypeError: isinstance() arg 2 must be a type or tuple of types

# %%
type(y_new[0])
# Out:
# numpy.float64

# %%
# Out:
# array([[0.08080808],
#        [0.61616162],
#        [0.36363636],
#        [0.96969697],
#        [0.50505051],
#        [0.43434343],
#        [0.23232323],
#        [0.78787879],
#        [0.58585859],
#        [0.31313131],
#        [0.95959596],
#        [0.87878788],
#        [0.51515152],
#        [0.61616162],
#        [0.57575758],
#        [0.51515152],
#        [0.11111111],
#        [0.38383838],
#        [0.01010101],
#        [0.02020202],
#        [0.55555556],
#        [0.80808081],
#        [0.58585859],
#        [0.01010101],
#        [0.01010101],
#        [0.91919192],
#        [0.53535354],
#        [0.86868687],
#        [0.95959596],
#        [0.96969697],
#        [0.        ],
#        [0.18181818],
#        [0.01010101],
#        [0.52525253],
#        [0.43434343],
#        [0.8989899 ],
#        [0.31313131],
#        [0.6969697 ],
#        [0.31313131],
#        [0.67676768],
#        [0.54545455],
#        [0.74747475],
#        [0.55555556],
#        [0.16161616],
#        [0.37373737],
#        [0.23232323],
#        [0.68686869],
#        [0.97979798],
#        [0.6969697 ],
#        [0.85858586],
#        [0.1010101 ],
#        [0.15151515],
#        [0.96969697],
#        [0.72727273],
#        [0.58585859],
#        [0.6969697 ],
#        [0.7979798 ],
#        [0.92929293],
#        [0.02020202],
#        [0.19191919],
#        [0.58585859],
#        [0.35353535],
#        [0.18181818],
#        [0.8989899 ],
#        [0.66666667],
#        [0.18181818],
#        [0.19191919],
#        [0.95959596],
#        [0.70707071],
#        [0.51515152],
#        [0.32323232],
#        [0.39393939],
#        [0.38383838],
#        [0.81818182],
#        [0.        ],
#        [0.1010101 ],
#        [0.91919192],
#        [0.56565657],
#        [0.88888889],
#        [0.49494949],
#        [0.22222222],
#        [0.3030303 ],
#        [0.93939394],
#        [0.41414141],
#        [0.98989899],
#        [0.06060606],
#        [0.15151515],
#        [0.8989899 ],
#        [0.5959596 ],
#        [0.01010101],
#        [0.        ],
#        [0.47474747],
#        [0.11111111],
#        [0.68686869],
#        [0.36363636],
#        [0.31313131],
#        [0.08080808],
#        [0.98989899],
#        [0.18181818],
#        [0.47474747]])
